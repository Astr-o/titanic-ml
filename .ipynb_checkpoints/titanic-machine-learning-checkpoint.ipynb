# %%
import pandas as pd

test_df = pd.read_csv('./test.csv')
train_df = pd.read_csv('./train.csv')

train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# Remove Ticket, cabin, name

# %%
del train_df['Ticket']
del train_df['Cabin']
del train_df['Name']
del train_df['PassengerId']

# %%
train_df.head(10)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S
# 5         0       3    male   NaN      0      0   8.4583        Q
# 6         0       1    male  54.0      0      0  51.8625        S
# 7         0       3    male   2.0      3      1  21.0750        S
# 8         1       3  female  27.0      0      2  11.1333        S
# 9         1       2  female  14.0      1      0  30.0708        C

# %% [markdown]
# Convert Sex and Embarked to numeric

# %%
train_df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
train_df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train_df['Embarked'] = train_df['Embarked'].map({'S': int(0), 'C': int(1), 'Q': int(2)})

# %%
train_df.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    male  22.0      1      0   7.2500       0.0
# 1         1       1  female  38.0      1      0  71.2833       1.0
# 2         1       3  female  26.0      0      0   7.9250       0.0
# 3         1       1  female  35.0      1      0  53.1000       0.0
# 4         0       3    male  35.0      0      0   8.0500       0.0

# %%
train_df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
train_df['Sex'] = train_df['Sex'].map({'male':0, 'female':1})
train_df.head(5)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    0  22.0      1      0   7.2500       0.0
# 1         1       1    1  38.0      1      0  71.2833       1.0
# 2         1       3    1  26.0      0      0   7.9250       0.0
# 3         1       1    1  35.0      1      0  53.1000       0.0
# 4         0       3    0  35.0      0      0   8.0500       0.0

# %% [markdown]
# Check nulls

# %%
train_df.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Fare        False
# Embarked     True
# dtype: bool

# %%
train_df['Embarked'].isnull().sum()
# Out:
# 2

# %%
train_df = train_df[~train_df['Embarked'].isnull()]

# %%
train_df['Embarked'].isnull().sum()
# Out:
# 0

# %%
train_df['Age'].isnull().sum()
# Out:
# 177

# %% [markdown]
# Replace nulls with mean

# %%
mean_age = train_df[train_df['Age'] == train_df['Age']]['Age'].mean()
mean_age
# Out:
# 29.642092696629209

# %%
train_df['Age'].fillna(mean_age, inplace=True)

train_df['Age'].mean()
# Out:
# 29.642092696629216

# %%
train_df.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Sex         False
# Age         False
# SibSp       False
# Parch       False
# Fare        False
# Embarked    False
# dtype: bool

# %%
train_df.head(10)
# Out:
#    Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         0       3    0  22.000000      1      0   7.2500       0.0
# 1         1       1    1  38.000000      1      0  71.2833       1.0
# 2         1       3    1  26.000000      0      0   7.9250       0.0
# 3         1       1    1  35.000000      1      0  53.1000       0.0
# 4         0       3    0  35.000000      0      0   8.0500       0.0
# 5         0       3    0  29.642093      0      0   8.4583       2.0
# 6         0       1    0  54.000000      0      0  51.8625       0.0
# 7         0       3    0   2.000000      3      1  21.0750       0.0
# 8         1       3    1  27.000000      0      2  11.1333       0.0
# 9         1       2    1  14.000000      1      0  30.0708       1.0

# %% [markdown]
# data visualisation

# %%
from matplotlib import pyplot as plt

# %%
set(train_df['Embarked'])
# Out:
# {0.0, 1.0, 2.0}

# %%
plt.hist(train_df[train_df['Survived'] == 1]['Fare'], 30)
plt.show()

# %%
plt.hist(train_df['Fare'], 30)
plt.show()

# %%
class_counts = train_df['Pclass'].value_counts()

# %%
plt.bar(class_counts.keys(), class_counts.values)
plt.xticks(class_counts.keys())
plt.show()

# %% [markdown]
# Splitting the data

# %%
from sklearn.model_selection import train_test_split

# %%
classes = ['Survived']
features = list(train_df.columns.delete(int(train_df.columns.equals('Survived'))))

print("classes: {0}, features: {1}".format(classes, features))
# Out:
# classes: ['Survived'], features: ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# %%
x = train_df[features].values
y = train_df[classes].values
split = 0.30

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=split, random_state=42)

# %% [markdown]
# Train Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()

nb_model.fit(x_train, y_train.ravel())
# Out:
# GaussianNB(priors=None)

# %%
from sklearn import metrics 
from sklearn.model_selection import GridSearchCV

def analyse_results(x, y, model, title):
    predict = model.predict(x)
    print ("=== " + title + " ===")
    
    if type(model) is GridSearchCV:
        print("Best values:{0}".format(model.best_estimator_))
    
    print("Accuracy: {0}".format(metrics.accuracy_score(y, predict)))
    
    print("Classification Report")
    print(metrics.classification_report(y, predict, labels=[0,1]))
    print()

# %%
analyse_results(x_train, y_train, nb_model, "Naive Bayese Training Data")
analyse_results(x_test, y_test, nb_model, "Naive Bayese Test Data")
# Out:
# === Naive Bayese Training Data ===
# Accuracy: 0.7990353697749196
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.82      0.86      0.84       382
#           1       0.76      0.71      0.73       240
#
# avg / total       0.80      0.80      0.80       622
#
#
# === Naive Bayese Test Data ===
# Accuracy: 0.7902621722846442
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.84      0.83       167
#           1       0.72      0.71      0.72       100
#
# avg / total       0.79      0.79      0.79       267

# %% [markdown]
# ## Train Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42, oob_score=True)
rf_model.fit(x_train, y_train.ravel())

analyse_results(x_train, y_train, rf_model, "Random Forest Training Data")
analyse_results(x_test, y_test, rf_model, "Random Forest Test Data")
# Out:
# === Random Forest Training Data ===
# Accuracy: 0.9807073954983923
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98       382
#           1       0.98      0.97      0.97       240
#
# avg / total       0.98      0.98      0.98       622
#
#
# === Random Forest Test Data ===
# Accuracy: 0.7640449438202247
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.79      0.84      0.82       167
#           1       0.71      0.63      0.67       100
#
# avg / total       0.76      0.76      0.76       267
# /usr/local/lib/python3.5/dist-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python3.5/dist-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(C=0.7, random_state=42)
lr_model.fit(x_train, y_train.ravel())

analyse_results(x_train, y_train, lr_model, "Logistic Regression Training Data")
analyse_results(x_test, y_test, lr_model, "Logistic Regression Test Data")
# Out:
# === Logistic Regression Training Data ===
# Accuracy: 0.7990353697749196
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.82      0.86      0.84       382
#           1       0.76      0.70      0.73       240
#
# avg / total       0.80      0.80      0.80       622
#
#
# === Logistic Regression Test Data ===
# Accuracy: 0.7865168539325843
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.82      0.84      0.83       167
#           1       0.73      0.69      0.71       100
#
# avg / total       0.78      0.79      0.79       267

# %%
from sklearn.linear_model import LogisticRegressionCV

lrc_model = LogisticRegressionCV(n_jobs=-1, random_state=42, Cs=50, cv=10, refit=True, class_weight="balanced")
lrc_model.fit(x_train, y_train.ravel())

analyse_results(x_train, y_train, lrc_model, "Logistic RegressionCV Training Data")
analyse_results(x_test, y_test, lrc_model, "Logistic RegressionCV Test Data")
# Out:
# === Logistic RegressionCV Training Data ===
# Accuracy: 0.792604501607717
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.84      0.81      0.83       382
#           1       0.72      0.76      0.74       240
#
# avg / total       0.80      0.79      0.79       622
#
#
# === Logistic RegressionCV Test Data ===
# Accuracy: 0.8014981273408239
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.88      0.79      0.83       167
#           1       0.70      0.82      0.76       100
#
# avg / total       0.81      0.80      0.80       267

# %%
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler 
import numpy as np
import time

def evaluate_models(df, models, title, print_train=False): 
    classes = ['Survived']
    features = list(df.columns.delete(int(train_df.columns.equals('Survived'))))

    print("========= Evaluating: {0} =========".format(title))
    print("classes: {0}, features: {1}".format(classes, features))
    print("Models: {0}".format(list(models.keys())))
    print()
    
    x = df[features].values
    y = df[classes].values
    split = 0.30

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=split, random_state=42)
    
    for k, model in models.items():
        
        start_time = time.time()
        model.fit(x_train, y_train.ravel())
        end_time = time.time()
        
        print("+++++++++++ {0} +++++++++++".format(k))
        print("Elasped Time {0}s".format(end_time - start_time))
        print()
 
        if print_train: 
            analyse_results(x_train, y_train, model, "{0} Training Data".format(k))
            
        analyse_results(x_test, y_test, model, "{0} Test Data".format(k))
        
mlp_parameters = {
    'mlp__learning_rate': ["constant", "invscaling", "adaptive"],
    'mlp__hidden_layer_sizes': [(100,10), (60, 10), (60, 5), (30, 10), (30, 5)],
    'mlp__alpha':   np.array([0.0001,0.00001, 0.000001, 0, 0]),
    'mlp__activation': ['relu']  #["logistic", "relu", "tanh"]
}

mlp_pipeline = Pipeline(steps=[('ss', StandardScaler()), ('mlp', MLPClassifier(solver='lbfgs'))])

mlp_cv = GridSearchCV(estimator=mlp_pipeline, param_grid=mlp_parameters, n_jobs=-1, scoring='accuracy', cv=10)

        
lrcv_parameters = {
    'lrcv__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag'],
    'lrcv__Cs': [10, 50, 100, 250, 500, 1000],
}

lrcv_pipeline = Pipeline(steps=[('ss', StandardScaler()), ('lrcv', LogisticRegressionCV(n_jobs=-1, cv=10, refit=True, class_weight="balanced"))])

lrcv_cv = GridSearchCV(estimator=lrcv_pipeline, param_grid=lrcv_parameters, n_jobs=-1, scoring='accuracy')

test_models = {"Logistic Regession CV": lrcv_cv,
              "Naive Bayese": GaussianNB(),
              "Random Forest": RandomForestClassifier(random_state=42, max_features=None),
              "SVC": SVC(kernel="linear"),
              #"MLP": mlp_cv 
              }
        
evaluate_models(train_df, test_models,  "Test 1")
# Out:
# ========= Evaluating: Test 1 =========
# classes: ['Survived'], features: ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
# Models: ['Logistic Regession CV', 'Naive Bayese', 'SVC', 'Random Forest']

# %%
train_df.head(10)
# Out:
#    Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         0       3    0  22.000000      1      0   7.2500       0.0
# 1         1       1    1  38.000000      1      0  71.2833       1.0
# 2         1       3    1  26.000000      0      0   7.9250       0.0
# 3         1       1    1  35.000000      1      0  53.1000       0.0
# 4         0       3    0  35.000000      0      0   8.0500       0.0
# 5         0       3    0  29.642093      0      0   8.4583       2.0
# 6         0       1    0  54.000000      0      0  51.8625       0.0
# 7         0       3    0   2.000000      3      1  21.0750       0.0
# 8         1       3    1  27.000000      0      2  11.1333       0.0
# 9         1       2    1  14.000000      1      0  30.0708       1.0

# %%
no_fare = train_df.drop("Fare", axis=1)
no_fare.head(10)
# Out:
#    Survived  Pclass  Sex        Age  SibSp  Parch  Embarked
# 0         0       3    0  22.000000      1      0       0.0
# 1         1       1    1  38.000000      1      0       1.0
# 2         1       3    1  26.000000      0      0       0.0
# 3         1       1    1  35.000000      1      0       0.0
# 4         0       3    0  35.000000      0      0       0.0
# 5         0       3    0  29.642093      0      0       2.0
# 6         0       1    0  54.000000      0      0       0.0
# 7         0       3    0   2.000000      3      1       0.0
# 8         1       3    1  27.000000      0      2       0.0
# 9         1       2    1  14.000000      1      0       1.0

# %%
evaluate_models(no_fare, test_models, "Test 2 - No Fare feature")
# Out:
# ========= Evaluating: Test 2 - No Fare feature =========
# classes: ['Survived'], features: ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked']
# Models: ['Logistic Regession CV', 'Naive Bayese', 'SVC', 'Random Forest']
#
# +++++++++++ Logistic Regession CV +++++++++++
# Elasped Time 2.4469521045684814s
#
# === Logistic Regession CV Test Data ===
# Accuracy: 0.797752808988764
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.88      0.78      0.83       167
#           1       0.69      0.82      0.75       100
#
# avg / total       0.81      0.80      0.80       267
#
#
# +++++++++++ Naive Bayese +++++++++++
# Elasped Time 0.0006968975067138672s
#
# === Naive Bayese Test Data ===
# Accuracy: 0.7790262172284644
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.84      0.80      0.82       167
#           1       0.69      0.74      0.71       100
#
# avg / total       0.78      0.78      0.78       267
#
#
# +++++++++++ SVC +++++++++++
# Elasped Time 0.09416675567626953s
#
# === SVC Test Data ===
# Accuracy: 0.7902621722846442
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.83      0.83       167
#           1       0.72      0.72      0.72       100
#
# avg / total       0.79      0.79      0.79       267
#
#
# +++++++++++ Random Forest +++++++++++
# Elasped Time 0.01573634147644043s
#
# === Random Forest Test Data ===
# Accuracy: 0.7827715355805244
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.81      0.85      0.83       167
#           1       0.73      0.67      0.70       100
#
# avg / total       0.78      0.78      0.78       267

# %% [markdown]
# ## Checking correlation

# %%
def plot_corrs(df):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    cax = ax.matshow(df.corr())
    fig.colorbar(cax)
    
    ax.set_xticklabels(['']+df.columns)
    ax.set_yticklabels(['']+df.columns)
    
    plt.show()
    
plot_corrs(train_df)

# %% [markdown]
# ## try no class

# %%
no_class = train_df.drop("Pclass", axis=1)
no_class.head(10)
# Out:
#    Survived  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         0    0  22.000000      1      0   7.2500       0.0
# 1         1    1  38.000000      1      0  71.2833       1.0
# 2         1    1  26.000000      0      0   7.9250       0.0
# 3         1    1  35.000000      1      0  53.1000       0.0
# 4         0    0  35.000000      0      0   8.0500       0.0
# 5         0    0  29.642093      0      0   8.4583       2.0
# 6         0    0  54.000000      0      0  51.8625       0.0
# 7         0    0   2.000000      3      1  21.0750       0.0
# 8         1    1  27.000000      0      2  11.1333       0.0
# 9         1    1  14.000000      1      0  30.0708       1.0

# %%
evaluate_models(no_class, test_models, "Test 3 - No Fare feature")
# Out:
# ========= Evaluating: Test 3 - No Fare feature =========
# classes: ['Survived'], features: ['Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
# Models: ['Logistic Regession CV', 'Naive Bayese', 'SVC', 'Random Forest']
#
# +++++++++++ Logistic Regession CV +++++++++++
# Elasped Time 2.2310993671417236s
#
# === Logistic Regession CV Test Data ===
# Accuracy: 0.7827715355805244
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.82      0.83       167
#           1       0.71      0.72      0.71       100
#
# avg / total       0.78      0.78      0.78       267
#
#
# +++++++++++ Naive Bayese +++++++++++
# Elasped Time 0.0006508827209472656s
#
# === Naive Bayese Test Data ===
# Accuracy: 0.8014981273408239
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.86      0.84       167
#           1       0.75      0.70      0.73       100
#
# avg / total       0.80      0.80      0.80       267
#
#
# +++++++++++ SVC +++++++++++
# Elasped Time 11.968454837799072s
#
# === SVC Test Data ===
# Accuracy: 0.7902621722846442
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.83      0.83       167
#           1       0.72      0.72      0.72       100
#
# avg / total       0.79      0.79      0.79       267
#
#
# +++++++++++ Random Forest +++++++++++
# Elasped Time 0.018212080001831055s
#
# === Random Forest Test Data ===
# Accuracy: 0.7790262172284644
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.80      0.86      0.83       167
#           1       0.73      0.65      0.69       100
#
# avg / total       0.78      0.78      0.78       267

# %% [markdown]
# ## No  Age

# %%
no_age = train_df.drop("Age", axis=1)
no_age.head(10)
# Out:
#    Survived  Pclass  Sex  SibSp  Parch     Fare  Embarked
# 0         0       3    0      1      0   7.2500       0.0
# 1         1       1    1      1      0  71.2833       1.0
# 2         1       3    1      0      0   7.9250       0.0
# 3         1       1    1      1      0  53.1000       0.0
# 4         0       3    0      0      0   8.0500       0.0
# 5         0       3    0      0      0   8.4583       2.0
# 6         0       1    0      0      0  51.8625       0.0
# 7         0       3    0      3      1  21.0750       0.0
# 8         1       3    1      0      2  11.1333       0.0
# 9         1       2    1      1      0  30.0708       1.0

# %%
evaluate_models(no_age, test_models, "Test 4 - No Age feature")
# Out:
# ========= Evaluating: Test 4 - No Age feature =========
# classes: ['Survived'], features: ['Pclass', 'Sex', 'SibSp', 'Parch', 'Fare', 'Embarked']
# Models: ['Logistic Regession CV', 'Naive Bayese', 'SVC', 'Random Forest']
#
# +++++++++++ Logistic Regession CV +++++++++++
# Elasped Time 2.3292665481567383s
#
# === Logistic Regession CV Test Data ===
# Accuracy: 0.7865168539325843
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.89      0.75      0.82       167
#           1       0.67      0.84      0.75       100
#
# avg / total       0.81      0.79      0.79       267
#
#
# +++++++++++ Naive Bayese +++++++++++
# Elasped Time 0.000690460205078125s
#
# === Naive Bayese Test Data ===
# Accuracy: 0.7827715355805244
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.82      0.83      0.83       167
#           1       0.71      0.70      0.71       100
#
# avg / total       0.78      0.78      0.78       267
#
#
# +++++++++++ SVC +++++++++++
# Elasped Time 12.770916223526001s
#
# === SVC Test Data ===
# Accuracy: 0.7902621722846442
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.83      0.83       167
#           1       0.72      0.72      0.72       100
#
# avg / total       0.79      0.79      0.79       267
#
#
# +++++++++++ Random Forest +++++++++++
# Elasped Time 0.015908241271972656s
#
# === Random Forest Test Data ===
# Accuracy: 0.7865168539325843
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.81      0.87      0.84       167
#           1       0.75      0.65      0.70       100
#
# avg / total       0.78      0.79      0.78       267

# %% [markdown]
# ## No Fare & No class

# %%
no_fare_class = train_df.drop("Pclass", axis=1).drop("Fare", axis=1)
no_fare_class.head(5)
# Out:
#    Survived  Sex   Age  SibSp  Parch  Embarked
# 0         0    0  22.0      1      0       0.0
# 1         1    1  38.0      1      0       1.0
# 2         1    1  26.0      0      0       0.0
# 3         1    1  35.0      1      0       0.0
# 4         0    0  35.0      0      0       0.0

# %%
evaluate_models(no_fare_class, test_models, "Test 5 - No Age feature")
# Out:
# ========= Evaluating: Test 5 - No Age feature =========
# classes: ['Survived'], features: ['Sex', 'Age', 'SibSp', 'Parch', 'Embarked']
# Models: ['Logistic Regession CV', 'Naive Bayese', 'SVC', 'Random Forest']
#
# +++++++++++ Logistic Regession CV +++++++++++
# Elasped Time 1.8065969944000244s
#
# === Logistic Regession CV Test Data ===
# Accuracy: 0.7940074906367042
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.84      0.84       167
#           1       0.73      0.72      0.72       100
#
# avg / total       0.79      0.79      0.79       267
#
#
# +++++++++++ Naive Bayese +++++++++++
# Elasped Time 0.0007603168487548828s
#
# === Naive Bayese Test Data ===
# Accuracy: 0.8014981273408239
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.82      0.87      0.85       167
#           1       0.76      0.69      0.72       100
#
# avg / total       0.80      0.80      0.80       267
#
#
# +++++++++++ SVC +++++++++++
# Elasped Time 0.050792694091796875s
#
# === SVC Test Data ===
# Accuracy: 0.7902621722846442
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.83      0.83      0.83       167
#           1       0.72      0.72      0.72       100
#
# avg / total       0.79      0.79      0.79       267
#
#
# +++++++++++ Random Forest +++++++++++
# Elasped Time 0.016212940216064453s
#
# === Random Forest Test Data ===
# Accuracy: 0.7640449438202247
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.80      0.83      0.81       167
#           1       0.69      0.66      0.68       100
#
# avg / total       0.76      0.76      0.76       267
